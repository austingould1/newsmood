# %%
# Initialize Sentiment Analyzer 
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import tweepy
import time
import pandas 
import matplotlib.pyplot as plt
import requests as req
import json
import random 
import numpy
analyzer = SentimentIntensityAnalyzer()
consumer_key ="OXIssui06lxnfblyDvyggPZDf"
consumer_secret ="NrYzmgtyU9grTqJPXR1I9VRMJZ7ViIaYluLLSpqa0bQZ713Rli"
access_token ="326281341-haVlmBoQsZbodflSAbbunuRwnqvuOEynygFeu4XZ"
access_secret = "askACO40IXdUOqMvVcIEGW5lO1gW8zMwOUkGYeEa80XCK"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
target_user = "austindudeguy"
tweet_text=[]
for x in range(5):
    public_tweets = api.user_timeline(target_user, page=x)
   
    for tweet in public_tweets:
        text = tweet["text"]
        tweet_text.append(text)

# %%
len(tweet_text)
# Out:
# 100

# %%
tweet_text[0]
# Out:
# '#ThisIsTexas #hookem 🤘🏼 https://t.co/ZZ0XBWMjan'

# %%
compound_austin=[]
for austindudeguy in tweet_text:
    results = analyzer.polarity_scores(austindudeguy)
    compound = results["compound"]
    compound_austin.append(compound)

# %%
plt.figure(figsize=(10, 10))
plt.scatter(x = range(100), y =compound_austin, label="austindudeguy")
plt.xlim(100, -1)
plt.xlabel("tweets ago")
plt.ylabel("tweets popularity")
plt.title("Sentiment Analysis of Media Tweets")
plt.legend()

plt.show()

# %%
austin_mean = numpy.mean(compound_austin)

# %%
austin_mean = numpy.mean(compound_austin)
plt.bar(left=1, height= austin_mean, color="skyblue")
plt.show()
